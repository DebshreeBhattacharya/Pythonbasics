# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## plot y=x

# %%
num_samples=20
x=np.linspace(20,100,num_samples) # 10 samples between 2 and 10 # input vector
y=x # output vector to be equal to x 
_=plt.plot(x,y)

# %% [markdown]
# ## plot y=x

# %%
num_samples=2
x=np.linspace(20,100,num_samples) # 10 samples between 2 and 10 # input vector
y=x # output vector to be equal to x 
_=plt.plot(x,y)

# %% [markdown]
# ## plot y=x

# %%
num_samples=202
x=np.linspace(20,100,num_samples) # 10 samples between 2 and 10 # input vector
y=x # output vector to be equal to x 
_=plt.plot(x,y)

# %%
# plot y=x
num_samples=20
x=np.linspace(2,10,num_samples) # 10 samples between 2 and 10 # input vector
y=x # output vector to be equal to x 
_=plt.plot(x,y)

# %%
# plot y=sin(x)
num_samples=2000
x=np.linspace(2,10,num_samples) # input vector x
#print(x)
y=np.log(x)  #output vector
_=plt.plot(x,y)

# %%
# plot y=sin(x)
num_samples=2000
x=np.linspace(2,10,num_samples) # input vector x
#print(x)
y=np.exp(x)  #output vector
_=plt.plot(x,y)

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
_=ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
_=ax.plot([26,50,75], [1, 4, 15])  # Plot some data on the axes.

# %%
plt.plot([52,49,25],[166,25,800])

# %%
import random

# %%
print (random.uniform(20,60)) #returns a random floating number between the two specified number
# Out:
# 51.86792422072767

# %%
# plot arbitrary lines
x=np.round(np.random.uniform(0,10,10),decimals=1) 
y=np.round(np.random.uniform(0,10,10),decimals=1)
#print(list(zip(x,y)))
plt.figure(figsize=(10,10))
_=plt.plot(x,y)

# %%
x=np.round(np.random.uniform(0,10,10),decimals=1)
print (x)
plt.plot(x)
# Out:
# [ 6.9 10.   0.3  2.8  0.   9.6  7.8  6.7  9.3  8.3]

# %%
y=np.round(np.random.uniform(0,10,10),decimals=1)
print (y)
plt.plot(y)
# Out:
# [5.7 8.4 8.3 4.4 7.6 6.2 7.5 2.7 0.7 9.1]

# %%
x=np.round(np.random.uniform(0,10,10),decimals=1)
y=np.round(np.random.uniform(0,10,10),decimals=1)
print(list(zip(x,y)))
#plt.figure(figsize=(10,10))
_=plt.plot(x,y)
# Out:
# [(6.3, 9.0), (7.6, 3.9), (5.0, 3.7), (5.6, 8.4), (0.9, 9.7), (2.5, 8.3), (8.4, 8.5), (7.5, 7.8), (4.2, 5.3), (8.4, 4.6)]

# %%
x=np.round(np.random.uniform(0,10,10),decimals=1)
y=np.round(np.random.uniform(0,10,10),decimals=1)
z=np.round(np.random.uniform(0,10,10),decimals=1)
print(list(zip(x,y,z)))
_=plt.plot(x,y,z)
# Out:
# [(4.4, 7.3, 7.5), (8.4, 3.3, 9.4), (1.7, 5.3, 7.6), (5.0, 0.9, 0.2), (9.8, 7.0, 0.6), (1.2, 8.0, 4.2), (4.3, 5.2, 2.6), (2.9, 3.4, 5.3), (1.2, 9.9, 7.8), (0.9, 4.6, 4.7)]

# %%
# plot multiple lines 

num_samples=5
num_lines=10
for i in range(0,num_lines):
    x=np.linspace(2,10,num_samples) #initialising the input array
    y=(i/num_lines)*x + 1 #initialise the output array
    print(y)
    _=plt.plot(x,y) #plot thm together
# Out:
# [1. 1. 1. 1. 1.]
# [1.2 1.4 1.6 1.8 2. ]
# [1.4 1.8 2.2 2.6 3. ]
# [1.6 2.2 2.8 3.4 4. ]
# [1.8 2.6 3.4 4.2 5. ]
# [2. 3. 4. 5. 6.]
# [2.2 3.4 4.6 5.8 7. ]
# [2.4 3.8 5.2 6.6 8. ]
# [2.6 4.2 5.8 7.4 9. ]
# [ 2.8  4.6  6.4  8.2 10. ]

# %%
# plot multiple lines 

num_samples=5
num_lines=15
for i in range(0,num_lines):
    x=np.linspace(0,10,num_samples) #initialising the input array
    y=(i/num_lines)*x + 1 #initialise the output array y=mx+c
    print(y)
    _=plt.plot(x,y) #plot thm together
# Out:
# [1. 1. 1. 1. 1.]
# [1.         1.16666667 1.33333333 1.5        1.66666667]
# [1.         1.33333333 1.66666667 2.         2.33333333]
# [1.  1.5 2.  2.5 3. ]
# [1.         1.66666667 2.33333333 3.         3.66666667]
# [1.         1.83333333 2.66666667 3.5        4.33333333]
# [1. 2. 3. 4. 5.]
# [1.         2.16666667 3.33333333 4.5        5.66666667]
# [1.         2.33333333 3.66666667 5.         6.33333333]
# [1.  2.5 4.  5.5 7. ]
# [1.         2.66666667 4.33333333 6.         7.66666667]
# [1.         2.83333333 4.66666667 6.5        8.33333333]
# [1. 3. 5. 7. 9.]
# [1.         3.16666667 5.33333333 7.5        9.66666667]
# [ 1.          3.33333333  5.66666667  8.         10.33333333]

# %%
# plot multiple lines with labels

num_samples=5
num_lines=10
for i in range(0,num_lines):
    x=np.linspace(2,10,num_samples)
    y=(i/num_lines)*x + 1
    _=plt.plot(x,y,label="slope_"+str(i)) # plt.plot(x,y, label='slope_'+str(i))
_=plt.legend()
#plt.show()

# %%
# plot a circle
num_samples=500
x=np.linspace(-1,1,num_samples) # 500 samples between -1 and 1
y=np.sqrt(1-x**2) #initialise the output
_=plt.plot(x,y)
_=plt.plot(x,-y)
_=plt.legend(["blue", "orange"],loc ="lower right") #loc for legend allignment
_=plt.title("circle",fontsize = 40)
plt.xlabel('x') # to markX & Y axis
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(x,y)

# %%
num_samples=10
data=np.random.uniform(1,5,(num_samples,2)) # data is a 2d np array of shape(10,2)

print(data.shape)
plt.scatter(data[:,0],data[:,1]) # plot x,y coordinates using 1dim as x and 2dim as y
# Out:
# (10, 2)

# %%
# scatter plot
num_samples=10
data=np.random.uniform(1,5,(num_samples,2)) # data is a 2d np array of shape(10,2)
print(data.shape)
plt.scatter(data[:,0],data[:,1]) # plot x,y coordinates using 1dim as x and 2dim as y

num_samples=5
data=np.random.uniform(10,15,(num_samples,2))
print(data.shape)
_=plt.scatter(data[:,0],data[:,1])

num_samples=20
data=np.random.uniform(20,25,(num_samples,2))
print(data.shape)
_=plt.scatter(data[:,0],data[:,1])
plt.xlabel('x Axis',fontsize = 20) # to markX & Y axis
plt.ylabel('y axis',fontsize = 20)
_=plt.title("SCATTER",fontsize = 30)
_=plt.legend(["blue", "orange", "green"],loc ="lower right") #loc for legend allignment
_=plt.grid() # to mark the grids
#_=plt.spines()
plt.plot()
#plt.figure(figsize=(5,5))
#plt.scatter
#ax.scatter
# Out:
# (10, 2)
# (5, 2)
# (20, 2)

# %%
# line labels, colors and markers
# adding a legend
# fmt
num_samples=500
x=np.linspace(-1,1,num_samples)
y=np.sqrt(1-x**2)
plt.figure(figsize=(10,10))  # to change the size of fig
plt.scatter(x,y,label="top",marker="x",color="green") #plt.plot(x,y, label='legend/info', marker, )
plt.plot(x,-y,label="bottom",marker="o",color="black",linewidth="5",markersize=10,markerfacecolor="r")
_=plt.legend()

# %%
# title, ticks, labels, grid
num_samples=20
x=np.linspace(-1,1,num_samples)
y=np.sqrt(1-x**2)
plt.figure(figsize=(10,10))
plt.plot(x,y,label="top",marker="x",color="r")
plt.plot(x,-y,label="bottom",marker="o",color="b")

plt.title("A circle: This is the title",fontsize = 20)
plt.xlabel("this is x label",fontsize = 15)
plt.ylabel("this is y label",fontsize = 15)

plt.xticks(np.linspace(-2,2,25))
plt.yticks(np.linspace(-1,1,5))

_=plt.legend()

# %%
# scatter markers
# scatter size

# scatter plot
num_samples=50
data=np.random.uniform(1,3.5,(num_samples,2))
print(data.shape)

alphas = np.linspace(0.1, 1, num_samples)
rgba_colors = np.zeros((num_samples,4)) # in rgba, a stands for transparancy
# for red the first column needs to be one
rgba_colors[:,0] = 1.0
# the fourth column needs to be your alphas
rgba_colors[:, 3] = alphas

plt.figure(figsize=(10,10))
plt.scatter(data[:,0],data[:,1],c=rgba_colors,s=40,marker="o",label="women")

num_samples=50
data=np.random.uniform(2,5,(num_samples,2))
print(data.shape)
markersizes=np.linspace(10,80,num_samples)
#print(markersizes)
plt.scatter(data[:,0],data[:,1],c="g",s=markersizes,marker='s',label="men")
#plt.scatter(data[:,0],data[:,1],c=rgba_colors,s=markersizes,marker='s',label="men")

plt.title("Analysis of pro basketball performance w.r.t height, gender, and age")
plt.xlabel("average score")
plt.ylabel("height")
_=plt.legend()
# Out:
# (50, 2)
# (50, 2)

# %%
x = np.linspace(0, 2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig,ax = plt.subplots(1,1)  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.plot(x, x**4, label='fourth')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %%
import numpy as np 
import matplotlib.pyplot as plt

X_train = np.array([[1,1], [2,2.5], [3, 1], [8, 7.5], [7, 9], [9, 9]])
Y_train = ['red', 'red', 'red', 'blue', 'blue', 'blue']

plt.figure()
plt.scatter(X_train[:, 0], X_train[:, 1], s = 170, color = Y_train[:])
plt.show()
print(X_train)
# Out:
# [[1.  1. ]
#  [2.  2.5]
#  [3.  1. ]
#  [8.  7.5]
#  [7.  9. ]
#  [9.  9. ]]

# %%
# if we want seperate graph in seperate figure?


x = np.linspace(0, 2, 100)


#fig,ax = plt.subplots() = fig, ax = plt.suplots(1,1)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots(2,2)  # Create a figure and an axes.
ax[0][0].plot(x, x, label='linear', color='orange')  # Plot some data on the axes.
ax[0][1].plot(x, x**2, label='quadratic', color='red')  # Plot more data on the axes...
ax[1][0].plot(x, x**3, label='cubic', color='g')  # ... and some more.
ax[1][1].plot(x, x**4, label='fourth')  # ... and some more.
#ax.set_xlabel('x label')  # Add an x-label to the axes.
#ax.set_ylabel('y label')  # Add a y-label to the axes.
#ax.set_title("Simple Plot")  # Add a title to the axes.
#ax.legend()  # Add a legend.

# %%
import math 

num_samples=150

# subplots example
NUM_PLOTS=8
num_columns=4
num_rows=NUM_PLOTS//4
fig,axes=plt.subplots(num_rows,num_columns,figsize=(4*num_columns,4*num_rows))
print(axes)
for i in range(0,NUM_PLOTS):
    myax=axes[math.floor(i/num_columns)][i%num_columns]
    myax.set_title("y=x^"+str(i),fontweight="bold",size="12")
    x=np.linspace(-5,5,num_samples)
    y=x**i
    myax.plot(x,y,color="r")
# Out:
# [[<AxesSubplot: > <AxesSubplot: > <AxesSubplot: > <AxesSubplot: >]
#  [<AxesSubplot: > <AxesSubplot: > <AxesSubplot: > <AxesSubplot: >]]

# %%
# generate points in order (theta) and plot
num_sides=6
radius=1
theta=2*np.pi/num_sides * np.arange(0,num_sides+1,1)
x=radius * np.cos(theta)
y=radius * np.sin(theta)
plt.figure(figsize=(10,10))
plt.plot(x,y)

# %%
# generate points in order (theta) and plot
num_sides=3
radius=1
theta=2*np.pi/num_sides * np.arange(0,num_sides+1,1)
x=radius * np.cos(theta)
y=radius * np.sin(theta)
plt.figure(figsize=(10,10))
plt.plot(x,y)

# %%
# generate points in order (theta) and plot
num_sides=4
radius=1
theta=2*np.pi/num_sides * np.arange(0,num_sides+1,1)
x=radius * np.cos(theta)
y=radius * np.sin(theta)
plt.figure(figsize=(10,10))
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# load image into numpy array
img=mpimg.imread("./images.jpg")
print(img,img.dtype,img.shape)
plt.figure(figsize=(10,10))
plt.imshow(img)
# Out:
# [[[ 41  55  68]
#   [ 42  56  69]
#   [ 41  57  70]
#   ...
#   [138 146 148]
#   [139 147 149]
#   [139 147 149]]
#
#  [[ 25  39  52]
#   [ 27  41  54]
#   [ 28  44  57]
#   ...
#   [138 146 148]
#   [138 146 148]
#   [139 147 149]]
#
#  [[ 27  41  54]
#   [ 27  41  54]
#   [ 26  42  55]
#   ...
#   [137 145 147]
#   [138 146 148]
#   [138 146 148]]
#
#  ...
#
#  [[ 77  42  48]
#   [ 57  22  28]
#   [ 72  35  42]
#   ...
#   [109  43  55]
#   [115  52  63]
#   [102  39  50]]
#
#  [[ 74  42  47]
#   [ 57  22  28]
#   [ 71  34  41]
#   ...
#   [111  47  61]
#   [112  48  62]
#   [102  38  52]]
#
#  [[ 65  33  38]
#   [ 50  15  21]
#   [ 65  28  35]
#   ...
#   [115  51  65]
#   [107  43  57]
#   [100  38  51]]] uint8 (172, 293, 3)

# %%
# Silly example data
bp_x = np.linspace(0, 2*np.pi, num=40, endpoint=True)
bp_y = np.sin(bp_x)

# Make the plot
plt.plot(bp_x, bp_y, linewidth=3, linestyle="--",
         color="blue", label=r"Legend label $\sin(x)$")
plt.xlabel(r"Description of $x$ coordinate (units)")
plt.ylabel(r"Description of $y$ coordinate (units)")
plt.title(r"Title here (remove for papers)")
plt.xlim(0, 2*np.pi)
plt.ylim(-1.1, 1.1)
plt.legend(loc="lower left")
plt.show()

# %%
# rgb to greyscale
# scale b/w 0 to 1
avg_image=np.sum(img,axis=2)/3
avg_image=avg_image.astype('uint8')
print(avg_image,avg_image.dtype,avg_image.shape)
plt.figure(figsize=(10,10))
plt.imshow(avg_image,cmap='gray', vmin=100, vmax=120)
# Out:
# [[ 54  55  56 ... 144 145 145]
#  [ 38  40  43 ... 144 144 145]
#  [ 40  40  41 ... 143 144 144]
#  ...
#  [ 55  35  49 ...  69  76  63]
#  [ 54  35  48 ...  73  74  64]
#  [ 45  28  42 ...  77  69  63]] uint8 (172, 293)

# %%
# discretize colors
red_channel=np.where(np.argmax(img,axis=2)==0,255,0) # np.argmax() function returns indices of the max element of the array in a particular axis.
red_channel=np.expand_dims(red_channel,axis=2) # np.where() function returns indices of the elements in an input array where the given condition is satisfied.

green_channel=np.where(np.argmax(img,axis=2)==1,255,0)
green_channel=np.expand_dims(green_channel,axis=2)

blue_channel=np.where(np.argmax(img,axis=2)==2,255,0)
blue_channel=np.expand_dims(blue_channel,axis=2)

discrete_color=np.concatenate([red_channel,green_channel,blue_channel],axis=2) #Join a sequence of arrays along an existing axis
plt.figure(figsize=(10,10))
plt.imshow(discrete_color)
